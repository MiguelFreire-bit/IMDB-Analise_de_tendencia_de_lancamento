# %% [markdown]
# ---
#
# # <span style="font-size: 35px;"> TMDB 5000 -  Análise de tendência de lançamento 🎬🎦</span>
# ---
#
#
#
#  <span style="font-size: 20px;">Análise de tendências de lançamentos: Identificar e visualizar as tendências de lançamentos de filmes ao longo do tempo, como número de lançamentos por ano, distribuição de lançamentos por gênero, etc.</span>

# %% [markdown]
# ---
# # DIA 1 - IMPORTAÇÃO E ESTATÍSTICAS DESCRITIVAS  👨‍💻
# ---

# %%
# IMPORTANDO BIBLIOTECAS PRINCIPAIS

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# IMPORTANDO BASE DE DADOS

df = pd.read_csv('tmdb_5000_movies.csv')
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
# RENOMEANDO AS COLUNAS

traducao = {
    'budget': 'Orçamento',
    'genres': 'Gêneros',
    'homepage': 'Página inicial',
    'id': 'ID',
    'keywords': 'Palavras-chave',
    'original_language': 'Idioma original',
    'original_title': 'Título original',
    'overview': 'Visão geral',
    'popularity': 'Popularidade',
    'production_companies': 'Empresas de produção',
    'production_countries': 'Países de produção',
    'release_date': 'Data de lançamento',
    'revenue': 'Receita',
    'runtime': 'Duração',
    'spoken_languages': 'Idiomas falados',
    'status': 'Status',
    'tagline': 'Slogan',
    'title': 'Título',
    'vote_average': 'Média de votos',
    'vote_count': 'Contagem de votos'
}

df = df.rename(columns=traducao)
df.head(2)
# Out:
#    Orçamento                                            Gêneros  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                  Página inicial     ID  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                       Palavras-chave Idioma original  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...              en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...              en
#
#                             Título original  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                          Visão geral  Popularidade  \
# 0  In the 22nd century, a paraplegic Marine is di...    150.437577
# 1  Captain Barbossa, long believed to be dead, ha...    139.082615
#
#                                 Empresas de produção  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
#
#                                   Países de produção Data de lançamento  \
# 0  [{"iso_3166_1": "US", "name": "United States o...         2009-12-10
# 1  [{"iso_3166_1": "US", "name": "United States o...         2007-05-19
#
#       Receita  Duração                                    Idiomas falados  \
# 0  2787965087    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 1   961000000    169.0           [{"iso_639_1": "en", "name": "English"}]
#
#      Status                                          Slogan  \
# 0  Released                     Enter the World of Pandora.
# 1  Released  At the end of the world, the adventure begins.
#
#                                      Título  Média de votos  Contagem de votos
# 0                                    Avatar             7.2              11800
# 1  Pirates of the Caribbean: At World's End             6.9               4500

# %%
# DANDO UMA OLHADA NA COLUNA DE LANÇAMENTOS

display(type(df['Data de lançamento'][0]))

#Converter representação de data em formato de string para um objeto de data no Python
 
from datetime import datetime

df['Data de lançamento'] = pd.to_datetime(df['Data de lançamento']) 

display(type(df['Data de lançamento'][0]))
# Out:
# str
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# ESTATÍSTICA DESCRITIVAS

df[['Orçamento', 'Média de votos', 'Data de lançamento',  'Contagem de votos']].describe()

# VERIFICANDO SE HÁ VALORES NULOS NA COLUNA 

display(df[df['Data de lançamento'].isnull() == True]) # claramente um filme sem dados suficientes, então ...

# removendo
df = df[df['Data de lançamento'].notnull()]
display(df.head(2))


# CRIAR COLUNA COM APENAS OS ANOS DE LANÇAMENTO

df['Ano de lancamento'] = df['Data de lançamento'].dt.year.astype(int)
display(df['Ano de lancamento'])
# Out:
#       Orçamento Gêneros Página inicial      ID Palavras-chave Idioma original  \
# 4553          0      []            NaN  380097             []              en
#
#                  Título original  \
# 4553  America Is Still the Place
#
#                                             Visão geral  Popularidade  \
# 4553  1971 post civil rights San Francisco seemed li...           0.0
#
#      Empresas de produção Países de produção Data de lançamento  Receita  \
# 4553                   []                 []                NaT        0
#
#       Duração Idiomas falados    Status Slogan                      Título  \
# 4553      0.0              []  Released    NaN  America Is Still the Place
#
#       Média de votos  Contagem de votos
# 4553             0.0                  0
#    Orçamento                                            Gêneros  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                  Página inicial     ID  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                       Palavras-chave Idioma original  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...              en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...              en
#
#                             Título original  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                          Visão geral  Popularidade  \
# 0  In the 22nd century, a paraplegic Marine is di...    150.437577
# 1  Captain Barbossa, long believed to be dead, ha...    139.082615
#
#                                 Empresas de produção  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
#
#                                   Países de produção Data de lançamento  \
# 0  [{"iso_3166_1": "US", "name": "United States o...         2009-12-10
# 1  [{"iso_3166_1": "US", "name": "United States o...         2007-05-19
#
#       Receita  Duração                                    Idiomas falados  \
# 0  2787965087    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 1   961000000    169.0           [{"iso_639_1": "en", "name": "English"}]
#
#      Status                                          Slogan  \
# 0  Released                     Enter the World of Pandora.
# 1  Released  At the end of the world, the adventure begins.
#
#                                      Título  Média de votos  Contagem de votos
# 0                                    Avatar             7.2              11800
# 1  Pirates of the Caribbean: At World's End             6.9               4500
# 0       2009
# 1       2007
# 2       2015
# 3       2012
# 4       2012
#         ...
# 4798    1992
# 4799    2011
# 4800    2013
# 4801    2012
# 4802    2005
# Name: Ano de lancamento, Length: 4802, dtype: int32

# %%
# ESTATÍSTICAS DESCRITIVAS

df[['Duração', 'Contagem de votos', 'Média de votos', 'Ano de lancamento']].describe()
# Out:
#            Duração  Contagem de votos  Média de votos  Ano de lancamento
# count  4800.000000        4802.000000     4802.000000        4802.000000
# mean    106.898125         690.361724        6.093440        2002.468763
# std      22.561593        1234.674268        1.191496          12.414354
# min       0.000000           0.000000        0.000000        1916.000000
# 25%      94.000000          54.000000        5.600000        1999.000000
# 50%     103.000000         235.500000        6.200000        2005.000000
# 75%     118.000000         737.000000        6.800000        2011.000000
# max     338.000000       13752.000000       10.000000        2017.000000

# %% [markdown]
# ---
#
# ## Observações Primárias ❗❗
#
# &nbsp;
#    * Podemos notar, por exemplo, que **75%** dos filmes tem uma duração menor do que 2 horas
#
#    * Provavelmente esse filme com **338 min** deve ser algum ruído, outlier, necessário verificar
#
#    * mesma observação se aplica a filme com duração **0**, necessario verificar
#
#    * é necessário avaliar a relevância de filmes sem votos a depender da análise que se recomenda
#
# &nbsp;
#
# ---

# %% [markdown]
# ---
# # DIA 2 - LIMPEZA E ADEQUAÇÃO DOS DADOS  👨‍💻
# ---

# %%
# LIMPEZA DE DADOS: NULOS E DUPLICATAS

# QUAIS COLUNAS O VALOR NULO REALMENTE ATRAPALHA?

display(df[df['Página inicial'].isnull() == True].head(2)) # aqui notamos não ser necessário apagar a linha, mas preencher o NaN
# Out:
#     Orçamento                                            Gêneros  \
# 15  225000000  [{"id": 12, "name": "Adventure"}, {"id": 10751...
# 24  207000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...
#
#    Página inicial    ID                                     Palavras-chave  \
# 15            NaN  2454  [{"id": 818, "name": "based on novel"}, {"id":...
# 24            NaN   254  [{"id": 774, "name": "film business"}, {"id": ...
#
#    Idioma original                           Título original  \
# 15              en  The Chronicles of Narnia: Prince Caspian
# 24              en                                 King Kong
#
#                                           Visão geral  Popularidade  \
# 15  One year after their incredible adventures in ...     53.978602
# 24  In 1933 New York, an overly ambitious movie pr...     61.226010
#
#                                  Empresas de produção  ... Data de lançamento  \
# 15  [{"name": "Walt Disney", "id": 5888}, {"name":...  ...         2008-05-15
# 24  [{"name": "WingNut Films", "id": 11}, {"name":...  ...         2005-12-14
#
#       Receita  Duração                           Idiomas falados    Status  \
# 15  419651413    150.0  [{"iso_639_1": "en", "name": "English"}]  Released
# 24  550000000    187.0  [{"iso_639_1": "en", "name": "English"}]  Released
#
#                              Slogan                                    Título  \
# 15             Hope has a new face.  The Chronicles of Narnia: Prince Caspian
# 24  The eighth wonder of the world.                                 King Kong
#
#    Média de votos  Contagem de votos  Ano de lancamento
# 15            6.3               1630               2008
# 24            6.6               2337               2005
#
# [2 rows x 21 columns]

# %%
# colunas
for valor in traducao.values():
    display(valor)
# Out:
# 'Orçamento'
# 'Gêneros'
# 'Página inicial'
# 'ID'
# 'Palavras-chave'
# 'Idioma original'
# 'Título original'
# 'Visão geral'
# 'Popularidade'
# 'Empresas de produção'
# 'Países de produção'
# 'Data de lançamento'
# 'Receita'
# 'Duração'
# 'Idiomas falados'
# 'Status'
# 'Slogan'
# 'Título'
# 'Média de votos'
# 'Contagem de votos'

# %% [markdown]
# ---
#
# ## Pensando em um primeiro filtro
#
# ---

# %%
display(len(df.query("Receita == 0")['Receita']))
display(len(df['Receita']))

#29% dos filmes não tem receita é uma fatia muito grande dos filmes do dataframe, naõ é um bom filtro.

display(len(df.query("`Contagem de votos` >= 20")['Contagem de votos']))

display(len(df['Contagem de votos']))

# 86% dos filmes tem mais de 20 votos, é um bom filtro
# Out:
# 1426
# 4802
# 4138
# 4802

# %%
df = df.query("`Contagem de votos` >= 20")

# %%
# filmes com duração 0

df.describe()
# Out:
#           Orçamento             ID  Popularidade       Receita      Duração  \
# count  4.138000e+03    4138.000000   4138.000000  4.138000e+03  4138.000000
# mean   3.333952e+07   47549.112615     24.745454  9.534649e+07   109.038183
# std    4.224039e+07   78793.779006     33.138051  1.718928e+08    20.736348
# min    0.000000e+00       5.000000      0.011697  0.000000e+00     0.000000
# 25%    4.000000e+06    7942.500000      7.629479  1.013447e+06    95.000000
# 50%    2.000000e+07   12086.500000     16.172035  3.190530e+07   105.000000
# 75%    4.500000e+07   44935.250000     31.791242  1.102243e+08   119.000000
# max    3.800000e+08  417859.000000    875.581305  2.787965e+09   338.000000
#
#        Média de votos  Contagem de votos  Ano de lancamento
# count     4138.000000        4138.000000        4138.000000
# mean         6.264306         799.880619        2002.352102
# std          0.862912        1297.044864          12.185775
# min          1.900000          20.000000        1916.000000
# 25%          5.700000         108.000000        1999.000000
# 50%          6.300000         325.000000        2005.000000
# 75%          6.900000         882.000000        2010.000000
# max          8.500000       13752.000000        2016.000000

# %% [markdown]
# ---
# ## Problemas
#
#    * resolvemos o problema de **contagem de votos e média de votos iguais a zero**, mas ainda existem filmes sem informação de **Duração** e **Receita**
#
# ---

# %%
display(df.sort_values(by='Duração',axis=0, ascending=True).head(10))

# só há um filme com duração igual a zero, fácil de ajustar. Vamos optar por filmes com ao menos 60 minutos

df = df.query("Duração >= 60")
# Out:
#       Orçamento                                            Gêneros  \
# 3809    4000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4709          0  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 4756      50000  [{"id": 27, "name": "Horror"}, {"id": 53, "nam...
# 1620   30000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 4673     200000                     [{"id": 35, "name": "Comedy"}]
# 2182          0  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 2805   12300000  [{"id": 16, "name": "Animation"}, {"id": 12, "...
# 3208          0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 4441     858000  [{"id": 16, "name": "Animation"}, {"id": 18, "...
# 1984   28000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                          Página inicial      ID  \
# 3809                                                NaN  158150
# 4709                                                NaN   13187
# 4756    http://www.cthulhulives.org/cocmovie/index.html   20981
# 1620                    http://disney.go.com/pooh/home/   51162
# 4673                                                NaN   43595
# 2182                                                NaN   13682
# 2805                                                NaN   12144
# 3208  http://www.starwars.com/tv-shows/star-wars-the...  333355
# 4441                     http://movies.disney.com/bambi    3170
# 1984                                                NaN   26672
#
#                                          Palavras-chave Idioma original  \
# 3809                                                 []              en
# 4709  [{"id": 65, "name": "holiday"}, {"id": 207317,...              en
# 4756  [{"id": 1523, "name": "obsession"}, {"id": 303...              en
# 1620  [{"id": 3905, "name": "owl"}, {"id": 4809, "na...              en
# 4673  [{"id": 10229, "name": "singer"}, {"id": 19484...              en
# 2182                                                 []              en
# 2805  [{"id": 746, "name": "vulkan"}, {"id": 936, "n...              en
# 3208  [{"id": 6091, "name": "war"}, {"id": 161176, "...              en
# 4441  [{"id": 5774, "name": "forest"}, {"id": 10683,...              en
# 1984  [{"id": 530, "name": "prophecy"}, {"id": 616, ...              en
#
#                        Título original  \
# 3809               How to Fall in Love
# 4709         A Charlie Brown Christmas
# 4756               The Call of Cthulhu
# 1620                   Winnie the Pooh
# 4673                She Done Him Wrong
# 2182            Pooh's Heffalump Movie
# 2805              The Land Before Time
# 3208  Star Wars: Clone Wars (Volume 1)
# 4441                             Bambi
# 1984         The Thief and the Cobbler
#
#                                             Visão geral  Popularidade  \
# 3809  An accountant, who never quite grew out of his...      1.923514
# 4709  When Charlie Brown complains about the overwhe...      8.701183
# 4756  A dying professor leaves his great-nephew a co...      1.777148
# 1620  During an ordinary day in Hundred Acre Wood, W...     19.143721
# 4673  New York singer and nightclub owner Lady Lou h...      0.622752
# 2182  Who or what exactly is a Heffalump? The lovabl...      9.031540
# 2805  An orphaned brontosaurus named Littlefoot sets...     28.670193
# 3208  The Saga continues with the Emmy-winning "Star...      1.881466
# 4441  Bambi's tale unfolds from season to season as ...     47.651878
# 1984  It is written among the limitless constellatio...      2.439184
#
#                                    Empresas de produção  ...  \
# 3809  [{"name": "Annuit Coeptis Entertainment Inc.",...  ...
# 4709  [{"name": "Warner Bros. Home Video", "id": 5173}]  ...
# 4756                   [{"name": "HPLHS", "id": 17827}]  ...
# 1620  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...
# 4673          [{"name": "Paramount Pictures", "id": 4}]  ...
# 2182        [{"name": "Walt Disney Pictures", "id": 2}]  ...
# 2805  [{"name": "Lucasfilm", "id": 1}, {"name": "Uni...  ...
# 3208  [{"name": "Lucasfilm", "id": 1}, {"name": "Car...  ...
# 4441  [{"name": "Walt Disney Productions", "id": 3166}]  ...
# 1984  [{"name": "Miramax Films", "id": 14}, {"name":...  ...
#
#      Data de lançamento    Receita  Duração  \
# 3809         2012-07-21          0      0.0
# 4709         1965-12-09          0     25.0
# 4756         2005-01-01          0     47.0
# 1620         2011-04-13   14460000     63.0
# 4673         1933-02-09    2200000     66.0
# 2182         2005-02-11          0     68.0
# 2805         1988-11-18   84460846     69.0
# 3208         2005-03-21          0     69.0
# 4441         1942-08-14  267447150     70.0
# 1984         1993-09-23     669276     72.0
#
#                                         Idiomas falados    Status  \
# 3809           [{"iso_639_1": "en", "name": "English"}]  Released
# 4709  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 4756           [{"iso_639_1": "en", "name": "English"}]  Released
# 1620           [{"iso_639_1": "en", "name": "English"}]  Released
# 4673           [{"iso_639_1": "en", "name": "English"}]  Released
# 2182           [{"iso_639_1": "en", "name": "English"}]  Released
# 2805           [{"iso_639_1": "en", "name": "English"}]  Released
# 3208           [{"iso_639_1": "en", "name": "English"}]  Released
# 4441           [{"iso_639_1": "en", "name": "English"}]  Released
# 1984           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                                  Slogan  \
# 3809                                                NaN
# 4709  That's what Christmas is all about, Charlie Br...
# 4756                                                NaN
# 1620                                           Oh Pooh.
# 4673         Mae West gives a 'Hot Time' to the nation!
# 2182    There's something new in the Hundred Acre Wood.
# 2805                           A new adventure is born.
# 3208                                                NaN
# 4441                                A great love story.
# 1984                                                NaN
#
#                                Título Média de votos  Contagem de votos  \
# 3809              How to Fall in Love            5.2                 20
# 4709        A Charlie Brown Christmas            7.5                153
# 4756              The Call of Cthulhu            6.9                 41
# 1620                  Winnie the Pooh            6.8                258
# 4673               She Done Him Wrong            5.1                 27
# 2182           Pooh's Heffalump Movie            6.4                 88
# 2805             The Land Before Time            7.0                640
# 3208  Star Wars: Clone Wars: Volume 1            8.0                 27
# 4441                            Bambi            6.8               1405
# 1984        The Thief and the Cobbler            6.8                 26
#
#       Ano de lancamento
# 3809               2012
# 4709               1965
# 4756               2005
# 1620               2011
# 4673               1933
# 2182               2005
# 2805               1988
# 3208               2005
# 4441               1942
# 1984               1993
#
# [10 rows x 21 columns]

# %%
df.describe()
# Out:
#           Orçamento             ID  Popularidade       Receita      Duração  \
# count  4.135000e+03    4135.000000   4135.000000  4.135000e+03  4135.000000
# mean   3.336272e+07   47537.100363     24.760408  9.541566e+07   109.099879
# std    4.224689e+07   78800.694796     33.145305  1.719359e+08    20.610410
# min    0.000000e+00       5.000000      0.011697  0.000000e+00    63.000000
# 25%    4.000000e+06    7927.500000      7.654747  1.078142e+06    95.000000
# 50%    2.000000e+07   12079.000000     16.183746  3.191279e+07   105.000000
# 75%    4.500000e+07   44927.500000     31.792472  1.104291e+08   119.000000
# max    3.800000e+08  417859.000000    875.581305  2.787965e+09   338.000000
#
#        Média de votos  Contagem de votos  Ano de lancamento
# count     4135.000000        4135.000000        4135.000000
# mean         6.264111         800.409190        2002.358162
# std          0.862795        1297.365904          12.175349
# min          1.900000          20.000000        1916.000000
# 25%          5.700000         108.000000        1999.000000
# 50%          6.300000         325.000000        2005.000000
# 75%          6.900000         882.500000        2010.000000
# max          8.500000       13752.000000        2016.000000

# %% [markdown]
# ---
#
# ## Por enquanto vamos manter como está em relação a Receita = 0 e Orcamento = 0
#
# Vamos averiguar os casos de filmes com **Durações** incomuns e esses altos valores para **Popularidade**
#
# ---

# %%
display(df.sort_values(by='Popularidade',axis=0, ascending=False).head(2))
# Out:
#      Orçamento                                            Gêneros  \
# 546   74000000  [{"id": 10751, "name": "Family"}, {"id": 16, "...
# 95   165000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...
#
#                         Página inicial      ID  \
# 546       http://www.minionsmovie.com/  211672
# 95   http://www.interstellarmovie.net/  157336
#
#                                         Palavras-chave Idioma original  \
# 546  [{"id": 3487, "name": "assistant"}, {"id": 179...              en
# 95   [{"id": 83, "name": "saving the world"}, {"id"...              en
#
#     Título original                                        Visão geral  \
# 546         Minions  Minions Stuart, Kevin and Bob are recruited by...
# 95     Interstellar  Interstellar chronicles the adventures of a gr...
#
#      Popularidade                               Empresas de produção  ...  \
# 546    875.581305  [{"name": "Universal Pictures", "id": 33}, {"n...  ...
# 95     724.247784  [{"name": "Paramount Pictures", "id": 4}, {"na...  ...
#
#     Data de lançamento     Receita  Duração  \
# 546         2015-06-17  1156730962     91.0
# 95          2014-11-05   675120017    169.0
#
#                               Idiomas falados    Status  \
# 546  [{"iso_639_1": "en", "name": "English"}]  Released
# 95   [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                                 Slogan        Título  \
# 546       Before Gru, they had a history of bad bosses       Minions
# 95   Mankind was born on Earth. It was never meant ...  Interstellar
#
#     Média de votos  Contagem de votos  Ano de lancamento
# 546            6.4               4571               2015
# 95             8.1              10867               2014
#
# [2 rows x 21 columns]

# %% [markdown]
# ---
#
# ## Por incrível que pareça, não me aparenta ser um `outlier` em popularidade. Acredito que há muitos `filmes impopulares` que puxam as estatísticas para `baixo`
#
# ---

# %%
display(df.sort_values(by='Duração',axis=0, ascending=False).head(2))
# Out:
#       Orçamento                                            Gêneros  \
# 2384   18000000  [{"id": 80, "name": "Crime"}, {"id": 18, "name...
# 1922          0  [{"id": 10752, "name": "War"}, {"id": 18, "nam...
#
#      Página inicial     ID                                     Palavras-chave  \
# 2384            NaN  43434  [{"id": 1419, "name": "gun"}, {"id": 7336, "na...
# 1922            NaN  10655  [{"id": 393, "name": "civil war"}, {"id": 4097...
#
#      Idioma original Título original  \
# 2384              en          Carlos
# 1922              en      Gettysburg
#
#                                             Visão geral  Popularidade  \
# 2384  The story of Venezuelan revolutionary, Ilich R...      1.138383
# 1922  Summer 1863. The Confederacy pushes north into...      5.529035
#
#                                    Empresas de produção  ...  \
# 2384  [{"name": "Egoli Tossell Film AG", "id": 2254}...  ...
# 1922  [{"name": "TriStar Television", "id": 8609}, {...  ...
#
#      Data de lançamento   Receita  Duração  \
# 2384         2010-05-19    871279    338.0
# 1922         1993-10-08  25000000    254.0
#
#                                         Idiomas falados    Status  \
# 2384  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 1922           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                               Slogan      Título Média de votos  \
# 2384  The man who hijacked the world      Carlos            6.7
# 1922                             NaN  Gettysburg            6.6
#
#       Contagem de votos  Ano de lancamento
# 2384                 50               2010
# 1922                 90               1993
#
# [2 rows x 21 columns]

# %% [markdown]
# ---
#
# ## Primeiro filme parece ser na verdade uma `minisérie` vamos então `retira-lo`
#
# ---

# %%
df = df.query('Duração < 338.0')

# %%
df.describe()
# Out:
#           Orçamento             ID  Popularidade       Receita      Duração  \
# count  4.134000e+03    4134.000000   4134.000000  4.134000e+03  4134.000000
# mean   3.336644e+07   47538.092888     24.766122  9.543853e+07   109.044509
# std    4.225133e+07   78810.201481     33.147278  1.719504e+08    20.302990
# min    0.000000e+00       5.000000      0.011697  0.000000e+00    63.000000
# 25%    4.000000e+06    7920.250000      7.664608  1.088933e+06    95.000000
# 50%    2.000000e+07   12031.000000     16.186159  3.195640e+07   105.000000
# 75%    4.500000e+07   44935.250000     31.792718  1.105286e+08   119.000000
# max    3.800000e+08  417859.000000    875.581305  2.787965e+09   254.000000
#
#        Média de votos  Contagem de votos  Ano de lancamento
# count     4134.000000        4134.000000        4134.000000
# mean         6.264006         800.590711        2002.356313
# std          0.862873        1297.470330          12.176242
# min          1.900000          20.000000        1916.000000
# 25%          5.700000         108.000000        1999.000000
# 50%          6.300000         325.000000        2005.000000
# 75%          6.900000         882.750000        2010.000000
# max          8.500000       13752.000000        2016.000000

# %%
# Obtém a contagem de filmes por ano
contagem_ano_de_lancamento = df['Ano de lancamento'].value_counts()
contagem_ano_de_lancamento.sort_values(axis=0, ascending=True).head(25)
# Out:
# 1925    1
# 1929    1
# 1941    1
# 1916    1
# 1934    1
# 1935    1
# 1938    1
# 1932    1
# 1936    1
# 1948    1
# 1958    1
# 1950    1
# 1927    1
# 1937    1
# 1942    2
# 1945    2
# 1949    2
# 1957    2
# 1947    2
# 1955    2
# 1959    2
# 1951    2
# 1933    2
# 1952    3
# 1956    3
# Name: Ano de lancamento, dtype: int64

# %% [markdown]
# ---
#
# ## Observamos, portanto, que existem muitos anos com poucos filmes, o que não é interessante para nossa análise.
#
# ---

# %%
# Filtra apenas os anos que tiveram mais de 15 filmes
anos_mais_de_15_filmes = contagem_ano_de_lancamento[contagem_ano_de_lancamento > 15].index

# Filtra o DataFrame original mantendo apenas os anos desejados
df = df[df['Ano de lancamento'].isin(anos_mais_de_15_filmes)]
display(df.shape)
df.describe()
# Out:
# (3918, 21)
#           Orçamento             ID  Popularidade       Receita      Duração  \
# count  3.918000e+03    3918.000000   3918.000000  3.918000e+03  3918.000000
# mean   3.487534e+07   49601.712353     24.976422  9.807173e+07   108.269270
# std    4.283194e+07   80403.171462     33.573364  1.750126e+08    19.192832
# min    0.000000e+00       5.000000      0.011697  0.000000e+00    63.000000
# 25%    5.000000e+06    8410.000000      7.747672  7.199450e+05    95.000000
# 50%    2.000000e+07   12274.000000     16.408233  3.349984e+07   105.000000
# 75%    5.000000e+07   49021.750000     31.953797  1.149447e+08   118.000000
# max    3.800000e+08  417859.000000    875.581305  2.787965e+09   254.000000
#
#        Média de votos  Contagem de votos  Ano de lancamento
# count     3918.000000        3918.000000        3918.000000
# mean         6.223175         816.342777        2004.433640
# std          0.850997        1315.320626           8.021739
# min          1.900000          20.000000        1980.000000
# 25%          5.700000         111.000000        2000.000000
# 50%          6.300000         333.000000        2006.000000
# 75%          6.800000         902.750000        2011.000000
# max          8.500000       13752.000000        2016.000000

# %%
vinte_anos = df.query('`Ano de lancamento` > 1996')

fig = plt.figure(figsize=(8, 3))

# Plotar o gráfico de contagem dos filmes por ano de lançamento
vinte_anos['Ano de lancamento'].value_counts().sort_index().plot(kind='bar')

plt.title('Número de filmes lançados após 1996')
plt.xlabel('Ano de lançamento')
plt.ylabel('Número de filmes')
plt.show()

# %% [markdown]
# ---
#
# ## podemos notar inicialmente que a partir de `2001` o número médio de filmes por anos tende a ser `estável`, com variações periódicas parecidas
#
# ---

# %%
# tentar outro gráfico, o de Linha

contagem_filmes = vinte_anos['Ano de lancamento'].value_counts().sort_index()


plt.figure(figsize=(10, 6))
sns.lineplot(x=contagem_filmes.index, y=contagem_filmes, lw=2, marker='o')
plt.grid(True)

# %% [markdown]
# ---
# ## Novas Observações
#
# >Tendência geral: Podemos observar a tendência geral do número de filmes lançados ao longo dos anos. Por exemplo, parece haver um aumento na quantidade de filmes lançados a partir de 1999 até 2010, seguido por uma queda gradual nos anos subsequentes.
#
# >Anos de destaque: Podemos identificar os anos em que houve um maior número de filmes lançados. Por exemplo, em 2008 e 2009, foram lançados 208 e 216 filmes, respectivamente, o que indica um período de alta atividade na indústria cinematográfica.
# ---

# %% [markdown]
# &nbsp;
#
# ---
#
# # DIA 3 - Analise Gráfica e outros Insights  👨‍💻
#
# ---
# &nbsp;

# %%
df.info() # ver se tem dados faltando, dados nulos ou algo assim
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3918 entries, 0 to 4798
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Orçamento             3918 non-null   int64
#  1   Gêneros               3918 non-null   object
#  2   Página inicial        1548 non-null   object
#  3   ID                    3918 non-null   int64
#  4   Palavras-chave        3918 non-null   object
#  5   Idioma original       3918 non-null   object
#  6   Título original       3918 non-null   object
#  7   Visão geral           3918 non-null   object
#  8   Popularidade          3918 non-null   float64
#  9   Empresas de produção  3918 non-null   object
#  10  Países de produção    3918 non-null   object
#  11  Data de lançamento    3918 non-null   datetime64[ns]
#  12  Receita               3918 non-null   int64
#  13  Duração               3918 non-null   float64
#  14  Idiomas falados       3918 non-null   object
#  15  Status                3918 non-null   object
#  16  Slogan                3461 non-null   object
#  17  Título                3918 non-null   object
#  18  Média de votos        3918 non-null   float64
#  19  Contagem de votos     3918 non-null   int64
#  20  Ano de lancamento     3918 non-null   int32
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(4), object(12)
# memory usage: 658.1+ KB

# %%
df.fillna('Não tem', axis = 0, inplace = True)

# %%
#Vamos comparar a tendência dos filmes de 1980 - 1998 com 1999 - 2016

oitenta_noventa = df.query('`Ano de lancamento` >= 1980 and `Ano de lancamento` <= 1998')
contagem_filmes_1 = oitenta_noventa['Ano de lancamento'].value_counts().sort_index()

noventa_dois_mil = df.query('`Ano de lancamento` >= 1999 and `Ano de lancamento` <= 2016')
contagem_filmes_2 = noventa_dois_mil['Ano de lancamento'].value_counts().sort_index()

# Criar a figura e os subplots
fig, axes = plt.subplots(2, 1, figsize=(10, 8))

# plot 1
axes[0].plot(contagem_filmes_1, lw=2, marker='o')
axes[0].set_title('1980 - 1998')

# plot 2
axes[1].plot(contagem_filmes_2, lw=2, marker='o')
axes[1].set_title('1999 - 2016')
# Out:
# Text(0.5, 1.0, '1999 - 2016')

# %% [markdown]
# ---
# ## Observações interessantes
#
# > Podemos notar um **crescimento** expressivo no número de filmes por ano na **década de 90**, um dos motivos pode ser o **avanço da tecnologia** na indústria cinematográfica, que possibilitou uma maior produção e distribuição de filmes.
#
# > Outro motivo também pode ter sido o surgimento do **CD** e **DVD**, que barateou muito o acesso a filmes em locadoras e talvez também encurtado o tempo que demorava entre o filme no cinema e em mídias físicas. Com isso, o cinema teria que produzir mais conteúdo para manter o interesse em produções novas. Porém, estamos apenas **supondo**
#
# > nos filmes da era **2000** notamos que já se estabeleceu um número relativamente alto de filmes por ano, mas com bastante variações. Diferente da **década de 90** não há somente um aumento na produção, mas também oscilações negativas.

# %% [markdown]
# ---
# # Quais meses do são mais movimentados em relação a lançamentos de filmes?
# ---

# %%
df['mes_lancamento'] = pd.to_datetime(df['Data de lançamento']).dt.month
grupo_por_mês = df.groupby('mes_lancamento')

# %%
grupo_por_mês['mes_lancamento'].value_counts()
# Out:
# mes_lancamento  mes_lancamento
# 1               1                 273
# 2               2                 277
# 3               3                 303
# 4               4                 278
# 5               5                 295
# 6               6                 308
# 7               7                 316
# 8               8                 340
# 9               9                 500
# 10              10                371
# 11              11                274
# 12              12                383
# Name: mes_lancamento, dtype: int64

# %%
filmes_por_mes = pd.DataFrame(grupo_por_mês['Título original'].count())
filmes_por_mes.index.name = 'mes'
filmes_por_mes.columns = ['quantidade']
filmes_por_mes
# Out:
#      quantidade
# mes
# 1           273
# 2           277
# 3           303
# 4           278
# 5           295
# 6           308
# 7           316
# 8           340
# 9           500
# 10          371
# 11          274
# 12          383

# %%
dicionario_meses = {1:'Jan',2:'Fev',3:'Mar',4:'Abr',
                    5:'Mai',6:'Jun',7:'Jul',8:'Ago',
                    9:'Set',10:'Out',11:'Nov',12:'Dez'}
filmes_por_mes.index = filmes_por_mes.index.map(dicionario_meses)

meses = list(dicionario_meses.values())
print(meses)

filmes_por_mes
# Out:
# ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
#      quantidade
# mes
# Jan         273
# Fev         277
# Mar         303
# Abr         278
# Mai         295
# Jun         308
# Jul         316
# Ago         340
# Set         500
# Out         371
# Nov         274
# Dez         383

# %%
meses = filmes_por_mes.index
valores = grupo_por_mês['mes_lancamento'].value_counts()

plt.figure(figsize=(10, 6))

# Plotagem do gráfico de barras
plt.plot(meses, valores,linewidth=2.5)

# Configurações do gráfico
plt.xlabel('Mês de lançamento')
plt.ylabel('Contagem')
plt.title('Contagem de Lançamento por Mês')
plt.grid(True)

# Exibição do gráfico
plt.show()

# %% [markdown]
# ---
#
# > levando em consideração **TODOS** os anos de lançamento dos filmes do Dataset temos o resultado acima. Não corresponde a intuição de maior número de lançamentos em períodos de **Férias**
#
# > **SETEMBRO** é muito deslocado dos demais

# %% [markdown]
# ---
# ## Para fins de comparação vamos escolher um ano em espefífico: 2012
# ---

# %%
df_2012 = df.query('`Ano de lancamento` == 2012')
df_2012.head(2)
# Out:
#    Orçamento                                            Gêneros  \
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                          Página inicial     ID  \
# 3    http://www.thedarkknightrises.com/  49026
# 4  http://movies.disney.com/john-carter  49529
#
#                                       Palavras-chave Idioma original  \
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...              en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...              en
#
#          Título original                                        Visão geral  \
# 3  The Dark Knight Rises  Following the death of District Attorney Harve...
# 4            John Carter  John Carter is a war-weary, former military ca...
#
#    Popularidade                               Empresas de produção  ...  \
# 3    112.312950  [{"name": "Legendary Pictures", "id": 923}, {"...  ...
# 4     43.926995        [{"name": "Walt Disney Pictures", "id": 2}]  ...
#
#       Receita Duração                           Idiomas falados    Status  \
# 3  1084939099   165.0  [{"iso_639_1": "en", "name": "English"}]  Released
# 4   284139100   132.0  [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                  Slogan                 Título Média de votos  \
# 3                       The Legend Ends  The Dark Knight Rises            7.6
# 4  Lost in our world, found in another.            John Carter            6.1
#
#   Contagem de votos  Ano de lancamento  mes_lancamento
# 3              9106               2012               7
# 4              2124               2012               3
#
# [2 rows x 22 columns]

# %%
grupo_por_mês_2012 = df_2012.groupby('mes_lancamento')

filmes_por_mes_2012 = pd.DataFrame(grupo_por_mês_2012['Título original'].count())
filmes_por_mes_2012.index.name = 'mes'
filmes_por_mes_2012.columns = ['quantidade']

dicionario_meses = {1:'Jan',2:'Fev',3:'Mar',4:'Abr',
                    5:'Mai',6:'Jun',7:'Jul',8:'Ago',
                    9:'Set',10:'Out',11:'Nov',12:'Dez'}
filmes_por_mes_2012.index = filmes_por_mes_2012.index.map(dicionario_meses)

meses = list(dicionario_meses.values())
print(meses)

filmes_por_mes_2012
# Out:
# ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
#      quantidade
# mes
# Jan          11
# Fev          10
# Mar          15
# Abr          18
# Mai          14
# Jun          17
# Jul           7
# Ago          23
# Set          28
# Out          13
# Nov          12
# Dez          10

# %%
meses_2012 = filmes_por_mes_2012.index
valores_2012 = grupo_por_mês_2012['mes_lancamento'].value_counts()

# Criar a figura e os subplots
fig, axes = plt.subplots(2, 1, figsize=(10, 8))

# plot 1
axes[0].plot(meses,valores, lw=2, marker='o')
axes[0].set_title('Todos os anos')

# plot 2
axes[1].plot(meses_2012, valores_2012, lw=2, marker='o')
axes[1].set_title('2012')
# Out:
# Text(0.5, 1.0, '2012')

# %% [markdown]
# ---
# ## Os meses finais apresentam uma tendência parecida com o resultado de todos os filmes, com uma grande elevação em **SETEMBRO**
# ---

# %% [markdown]
# # Vamos agora, em vez de considerar apenas um ano, coletar amostras de períodos diferentes.

# %%
def Amostra_anos (x, y):
    df_x = df.query('`Ano de lancamento` >= @x and `Ano de lancamento` <= @y')
    
    grupo_por_mês = df_x.groupby('mes_lancamento')
    
    filmes_por_mes = pd.DataFrame(grupo_por_mês['Título original'].count())
    filmes_por_mes.index.name = 'mes'
    filmes_por_mes.columns = ['quantidade']

    dicionario_meses = {1:'Jan',2:'Fev',3:'Mar',4:'Abr',
                    5:'Mai',6:'Jun',7:'Jul',8:'Ago',
                    9:'Set',10:'Out',11:'Nov',12:'Dez'}
    filmes_por_mes.index = filmes_por_mes.index.map(dicionario_meses)

    #meses = list(dicionario_meses.values())
    #print(meses)
    
    meses = filmes_por_mes.index
    valores = grupo_por_mês['mes_lancamento'].value_counts()


    return meses, valores

# %%
meses_1, Valores_1 = Amostra_anos (1980, 1988)
meses_2, Valores_2 = Amostra_anos (1989, 1997)
meses_3, Valores_3 = Amostra_anos (1998, 2006)
meses_4, Valores_4 = Amostra_anos (2007, 2016)

# %% [markdown]
# ---
#
#      no código acima estava sem consegui resolver um problema na função, vou armazenar a resposta aqui para não perder:
#
# O problema ocorre porque a expressão `x` e `y` na função `Amostra_anos` não está sendo substituída corretamente no comando `df.query()`. Isso acontece porque as variáveis `x` e `y` estão sendo interpretadas como nomes de colunas no DataFrame `df`, em vez de seus valores reais.
#
# Para resolver o problema, você pode modificar a função `Amostra_anos` da seguinte maneira:
#
# ```python
# def Amostra_anos (x, y):
#     df_x = df.query('`Ano de lancamento` >= @x and `Ano de lancamento` <= @y')
#
#     # Restante do código...
# ```
#
# Ao usar o símbolo `@` antes das variáveis `x` e `y` na expressão `df.query()`, você indica ao Pandas que essas variáveis devem ser substituídas por seus valores correspondentes.
#
# Com essa modificação, o erro deve ser resolvido e a função `Amostra_anos` deve funcionar corretamente.

# %%
# Criar a figura e os subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# plot 1
axes[0,0].plot(meses_1,Valores_1, lw=2, marker='o')
axes[0,0].set_title('1980 - 1988')

# plot 2
axes[0,1].plot(meses_2, Valores_2, lw=2, marker='o')
axes[0,1].set_title('1989 - 1997')

# plot 3
axes[1,0].plot(meses_3, Valores_3, lw=2, marker='o')
axes[1,0].set_title('1998 - 2006')

# plot 4
axes[1,1].plot(meses_4, Valores_4, lw=2, marker='o')
axes[1,1].set_title('2007 - 2016')
# Out:
# Text(0.5, 1.0, '2007 - 2016')

# %% [markdown]
# ---
# ## Observações interessantes
#
# > Como ja haviamos notado existe claramente alguma mudança no funcionamento da industria cinematográfica depois da **década de 80**, de **90** em diante há uma "padronização" nas **temporadas** de lançamentos de filme.
#
# > uma diferença da **90** e dos anos **2000** é que o crescimento da industria em 90 foi **exponencial**. Então precebe-se que a alta temporada começa em maio e depois não para de crescer
# ---

# %% [markdown]
# &nbsp;
#
# ---
#
# # DIA 4 - Análise por idioma - Tendência de lançamento  👨‍💻
#
# ---

# %% [markdown]
# ### Investigar a distribuição de lançamentos de filmes por idioma. É possível identificar os idiomas mais comuns e verificar se há alguma tendência de aumento ou diminuição ao longo do tempo.

# %%
def Amostra_linguas (x, y):
    df_x = df.query('`Ano de lancamento` >= @x and `Ano de lancamento` <= @y')
    
    grupo_por_linguas = df_x.groupby('Idioma original')
    
    filmes_por_linguas = pd.DataFrame(grupo_por_linguas['Título original'].count())
    filmes_por_linguas.index.name = 'Lingua'
    filmes_por_linguas.columns = ['quantidade']
    filmes_por_linguas = filmes_por_linguas.sort_values(by='quantidade', axis=0, ascending=False)[0:7]

    dicionario_linguas = {'en': 'Inglês', 'ja': 'Japonês', 'fr': 'Francês', 'zh': 'Chinês',
                     'ko': 'Coreano', 'te': 'Telugu', 'ru': 'Russo', 'cn': 'Chinês',
                     'es': 'Espanhol', 'it': 'Italiano', 'de': 'Alemão', 'nl': 'Holandês',
                     'sv': 'Sueco', 'th': 'Tailandês', 'da': 'Dinamarquês', 'xx': 'Desconhecido',
                     'hu': 'Húngaro', 'pt': 'Português', 'hi': 'Hindi', 'is': 'Islandês',
                     'cs': 'Tcheco', 'nb': 'Norueguês Bokmål', 'af': 'Africâner', 'pl': 'Polonês',
                     'he': 'Hebraico', 'ar': 'Árabe', 'id': 'Indonésio', 'ro': 'Romeno',
                     'fa': 'Persa (Farsi)', 'no': 'Norueguês', 'ps': 'Pashto', 'el': 'Grego'}

    filmes_por_linguas.index = filmes_por_linguas.index.map(dicionario_linguas)

    #meses = list(dicionario_meses.values())
    #print(meses)
    
    lingua = filmes_por_linguas.index
    valores = filmes_por_linguas['quantidade']


    return lingua, valores, filmes_por_linguas

# %%
lingua_1, Valores_1, filmes_por_linguas_1 = Amostra_linguas(1980, 1988)
lingua_2, Valores_2, filmes_por_linguas_2 = Amostra_linguas(1989, 1997)
lingua_3, Valores_3, filmes_por_linguas_3 = Amostra_linguas(1998, 2006)
lingua_4, Valores_4, filmes_por_linguas_4 = Amostra_linguas(2007, 2016)

# %%
# Criar a figura e os subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# plot 1
axes[0,0].bar(lingua_1,Valores_1, lw=2)
axes[0,0].set_title('1980 - 1988')

# plot 2
axes[0,1].bar(lingua_2, Valores_2, lw=2)
axes[0,1].set_title('1989 - 1997')

# plot 3
axes[1,0].bar(lingua_3, Valores_3, lw=2)
axes[1,0].set_title('1998 - 2006')

# plot 4
axes[1,1].bar(lingua_4, Valores_4, lw=2)
axes[1,1].set_title('2007 - 2016')
# Out:
# Text(0.5, 1.0, '2007 - 2016')

# %% [markdown]
# ---
# ### Aqui fica fácil de entender que independente da época a lingua inglesa é a mais falada, indiscutívelmente, o que atrapalha a visualização da distribuição das demais linguas. Vamos então retirar o inglês
# ---

# %%
def Amostra_linguas (x, y):
    df_x = df.query('`Ano de lancamento` >= @x and `Ano de lancamento` <= @y')
    
    grupo_por_linguas = df_x.groupby('Idioma original')
    
    filmes_por_linguas = pd.DataFrame(grupo_por_linguas['Título original'].count())
    filmes_por_linguas.index.name = 'Lingua'
    filmes_por_linguas.columns = ['quantidade']
    filmes_por_linguas = filmes_por_linguas.sort_values(by='quantidade', axis=0, ascending=False)[1:6]

    dicionario_linguas = {'en': 'Inglês', 'ja': 'Japonês', 'fr': 'Francês', 'zh': 'Chinês',
                     'ko': 'Coreano', 'te': 'Telugu', 'ru': 'Russo', 'cn': 'Chinês',
                     'es': 'Espanhol', 'it': 'Italiano', 'de': 'Alemão', 'nl': 'Holandês',
                     'sv': 'Sueco', 'th': 'Tailandês', 'da': 'Dinamarquês', 'xx': 'Desconhecido',
                     'hu': 'Húngaro', 'pt': 'Português', 'hi': 'Hindi', 'is': 'Islandês',
                     'cs': 'Tcheco', 'nb': 'Norueguês Bokmål', 'af': 'Africâner', 'pl': 'Polonês',
                     'he': 'Hebraico', 'ar': 'Árabe', 'id': 'Indonésio', 'ro': 'Romeno',
                     'fa': 'Persa (Farsi)', 'no': 'Norueguês', 'ps': 'Pashto', 'el': 'Grego'}

    filmes_por_linguas.index = filmes_por_linguas.index.map(dicionario_linguas)

    #meses = list(dicionario_meses.values())
    #print(meses)
    
    lingua = filmes_por_linguas.index
    valores = filmes_por_linguas['quantidade']


    return lingua, valores

# %%
lingua_1, Valores_1 = Amostra_linguas(1980, 1988)
lingua_2, Valores_2= Amostra_linguas(1989, 1997)
lingua_3, Valores_3 = Amostra_linguas(1998, 2006)
lingua_4, Valores_4 = Amostra_linguas(2007, 2016)

# %%
# Criar a figura e os subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# plot 1
axes[0,0].bar(lingua_1,Valores_1, lw=2)
axes[0,0].set_title('1980 - 1988')

# plot 2
axes[0,1].bar(lingua_2, Valores_2, lw=2)
axes[0,1].set_title('1989 - 1997')

# plot 3
axes[1,0].bar(lingua_3, Valores_3, lw=2)
axes[1,0].set_title('1998 - 2006')

# plot 4
axes[1,1].bar(lingua_4, Valores_4, lw=2)
axes[1,1].set_title('2007 - 2016')
# Out:
# Text(0.5, 1.0, '2007 - 2016')

# %% [markdown]
# ---
# ## Observações interessantes
#
# ``o idioma francês apresentou um crescimento significativo em termos de quantidade de filmes lançados, enquanto o idioma chinês também teve um aumento notável. Por outro lado, idiomas como japonês e espanhol mantiveram-se relativamente estáveis em relação ao número de filmes lançados``
# ---
#
# ``Podemos notar também que até 1997 o número de filmes com idioma diferente do inglês eram IRRISÓRIOS o que pode indicar uma valorização das industrias cinematográficas fora de Hollywood``
# ---
#
# ---

# %% [markdown]
# ---
# ### vamos tentar outra visualização
# ---

# %%
def Amostra_linguas_solo(x):
    Linguas_individualmente = pd.concat([
        filmes_por_linguas_1.query("Lingua == @x"),
        filmes_por_linguas_2.query("Lingua == @x"),
        filmes_por_linguas_3.query("Lingua == @x"),
        filmes_por_linguas_4.query("Lingua == @x")
    ])
    
    Linguas_individualmente = Linguas_individualmente.reset_index()
    
    dicionario_ano = {0:'(1980 - 1988)', 1:'(1989 - 1997)',2:'(1998 - 2006)',3:'(2007 - 2016)'}
    Linguas_individualmente.index = Linguas_individualmente.index.map(dicionario_ano)
    
    
    return Linguas_individualmente

# %%
Linguas_individualmente_1 = Amostra_linguas_solo('Inglês')
Linguas_individualmente_2 = Amostra_linguas_solo('Espanhol')
Linguas_individualmente_3 = Amostra_linguas_solo('Francês')
Linguas_individualmente_4 = Amostra_linguas_solo('Chinês')

# %%
# Criar a figura e os subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# plot 1
axes[0, 0].plot(Linguas_individualmente_1.index, Linguas_individualmente_1['quantidade'], lw=2, marker='o')
axes[0, 0].set_title('Inglês')
axes[0, 0].grid(True)

# plot 2
axes[0, 1].plot(Linguas_individualmente_2.index, Linguas_individualmente_2['quantidade'], lw=2, marker='o')
axes[0, 1].set_title('Espanhol')
axes[0, 1].grid(True)

# plot 3
axes[1, 0].plot(Linguas_individualmente_3.index, Linguas_individualmente_3['quantidade'], lw=2, marker='o')
axes[1, 0].set_title('Francês')
axes[1, 0].grid(True)

# plot 4
axes[1, 1].plot(Linguas_individualmente_4.index, Linguas_individualmente_4['quantidade'], lw=2, marker='o')
axes[1, 1].set_title('Chinês')
axes[1, 1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Observações interessantes
#
#
# ``Inglês cresceu (1997-2006) --> 250%``
# ---
# ``Espanhou cresceu (1997-2006)-- > 1100%``
# ---
# ``Francês cresceu (1997-2006) --> 2100%``
# ---
# ``Chinês cresceu (1997-2006) --> 133%``
# ---
#
# ---

# %% [markdown]
# &nbsp;
#
# ---
#
# # DIA 5 - Análise da relação Receita x Votos, dentre outros - Tendência de lançamento  👨‍💻
#
# ---

# %%
plt.scatter(x=df['Média de votos'], y=df['Receita'], marker='o' )
plt.xlabel('Média de votos')
plt.ylabel('Receita')
plt.title('Relação entre Avaliações e Receita dos Filmes')
plt.show()

# %%
correlation = df['Média de votos'].corr(df['Receita'])
print(f"Correlação entre Avaliações e Receita: {correlation:.2f}")
# Out:
# Correlação entre Avaliações e Receita: 0.21

# %% [markdown]
# ---
# ### É de se notar que há correlação entre receita e o número de votos não é tão significativa, a maioria dos pontos estão espalhados em uma grande área do gráfico
# ---

# %% [markdown]
# ``Tabela de correlação``
# ---

# %%
df.corr()
# Out:
# C:\Users\Miguel Freire\AppData\Local\Temp\ipykernel_17984\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    Orçamento        ID  Popularidade   Receita   Duração  \
# Orçamento           1.000000 -0.037541      0.478395  0.723443  0.299572
# ID                 -0.037541  1.000000      0.130686 -0.000868 -0.046984
# Popularidade        0.478395  0.130686      1.000000  0.628732  0.219953
# Receita             0.723443 -0.000868      0.628732  1.000000  0.277318
# Duração             0.299572 -0.046984      0.219953  0.277318  1.000000
# Média de votos      0.028505 -0.066312      0.283042  0.210599  0.398059
# Contagem de votos   0.576143  0.067388      0.761078  0.774241  0.300047
# Ano de lancamento   0.140333  0.580642      0.158704  0.087232 -0.091723
# mes_lancamento      0.040557 -0.023934      0.030367  0.045529  0.160270
#
#                    Média de votos  Contagem de votos  Ano de lancamento  \
# Orçamento                0.028505           0.576143           0.140333
# ID                      -0.066312           0.067388           0.580642
# Popularidade             0.283042           0.761078           0.158704
# Receita                  0.210599           0.774241           0.087232
# Duração                  0.398059           0.300047          -0.091723
# Média de votos           1.000000           0.373076          -0.106707
# Contagem de votos        0.373076           1.000000           0.147141
# Ano de lancamento       -0.106707           0.147141           1.000000
# mes_lancamento           0.122597           0.033142          -0.068165
#
#                    mes_lancamento
# Orçamento                0.040557
# ID                      -0.023934
# Popularidade             0.030367
# Receita                  0.045529
# Duração                  0.160270
# Média de votos           0.122597
# Contagem de votos        0.033142
# Ano de lancamento       -0.068165
# mes_lancamento           1.000000

# %% [markdown]
# ``ORÇAMENTO X RECEITA``
# ---

# %%
plt.scatter(x=df['Orçamento'], y=df['Receita'], marker='o', color='green' )
plt.xlabel('Orçamento')
plt.ylabel('Receita')
plt.title('Relação entre Orçamento e Receita dos Filmes')
plt.show()

# %% [markdown]
# ---
# ### Neste caso já conseguimos observar uma relação mais forte. Quando o Orçamento sobe a Receita tende a seguir, mas ainda assim não é uma correlação muito forte
# ---

# %%
import seaborn as sns

# Criar uma figura com tamanho personalizado
plt.figure(figsize=(10, 6))

# Filtrar apenas os filmes lançados a partir de 1980
filmes_recentes = df[df['Ano de lancamento'] >= 1980]

# Criar o histograma da duração dos filmes
sns.histplot(filmes_recentes['Duração'], bins=20, kde=True)

# Configurar os rótulos dos eixos
plt.xlabel('Duração')
plt.ylabel('Contagem')
plt.title('Distribuição da Duração dos Filmes')

# Exibir o histograma
plt.show()

# %% [markdown]
# ``Ano de lancamento X Duração``
# ---

# %%
plt.figure(figsize=(10, 6))


# Criar o histograma da duração dos filmes
sns.histplot(filmes_recentes['Duração'], bins=20, kde=True)

# Configurar os rótulos dos eixos
plt.xlabel('Duração')
plt.ylabel('Contagem')
plt.title('Distribuição da Duração dos Filmes')

plt.show()

# %% [markdown]
# ---
#
# # <span style="font-size: 35px;"> CONCLUSÕES</span>
# ---

# %% [markdown]
# > # 1. <span style="font-size: 20px;"> Podemos notar, por exemplo, que 75% dos filmes tem uma duração menor do que 2 horas</span>
# ---
#
# > # 2. <span style="font-size: 20px;">Notar inicialmente que, a partir de 2001, o número médio de filmes por anos tende a ser estável, com variações periódicas parecidas``</span>
# ---
#
# > # 3. <span style="font-size: 20px;">Podemos notar um crescimento expressivo no número de filmes por ano na década de 90, um dos motivos pode ser o avanço da tecnologia na indústria cinematográfica, que possibilitou uma maior produção e distribuição de filmes.``</span>
# ---
#
# > # 4. <span style="font-size: 20px;">Outro motivo também pode ter sido o surgimento do CD e DVD, que barateou muito o acesso a filmes em locadoras e talvez também encurtado o tempo que demorava entre o filme no cinema e em mídias físicas. Com isso, o cinema teria que produzir mais conteúdo para manter o interesse em produções novas. Porém, estamos apenas supondo``</span>
# ---
#
# > # 5. <span style="font-size: 20px;">levando em consideração TODOS os anos de lançamento dos filmes do Dataset temos o resultado acima. Não corresponde a intuição de maior número de lançamentos em períodos de Férias</span>
#
# > # 6. <span style="font-size: 20px;">SETEMBRO é muito deslocado dos demais, mês mais movimentado da indústria</span>
#
# > # 7. <span style="font-size: 20px;">Como ja haviamos notado existe claramente alguma mudança no funcionamento da industria cinematográfica depois da década de 80, de 90 em diante há uma "padronização" nas temporadas de lançamentos de filme.</span>
#
# > # 8. <span style="font-size: 20px;">o idioma francês apresentou um crescimento significativo em termos de quantidade de filmes lançados, enquanto o idioma chinês também teve um aumento notável. Por outro lado, idiomas como japonês e espanhol mantiveram-se relativamente estáveis em relação ao número de filmes lançados</span>
#
# > # 9. <span style="font-size: 20px;">Podemos notar também que até 1997 o número de filmes com idioma diferente do inglês eram IRRISÓRIOS o que pode indicar uma valorização das industrias cinematográficas fora de Hollywood</span>
